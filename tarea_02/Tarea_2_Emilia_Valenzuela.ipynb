# %% [markdown]
# Crea un programa que imprima los números desde -30 hasta 50.
#
# Para cada número, además de imprimirlo, el programa debe mostrar un texto según estas reglas:
#
# si el número es menor que 0, mostrar "Muy frío"
# si el número está entre 0 y 24, mostrar "Templado"
# si el número es mayor o igual a 25, mostrar "Caluroso"

# %%
# lista desde -30 al 50
# rango de números desde el -30 hasta 50 (51 no esta incluido)
lista_numeros = range(-30,51)

# se toma el valor de cada número dentro del rango
for x in range(-30,51):
# si el número es menor a 0, se considera "muy frío"
  if(x < 0):
    print(x,"muy frío")
# si el número está entre 0 y 24 (incluyendo ambos), es "templado"
  elif(x >= 0 and x <= 24):
    print(x, "Templado")
# si el número es mayor o igual a 25, es "caluroso"
  else:
    print(x, "caluroso")
# Out:
# -30 muy frío
# -29 muy frío
# -28 muy frío
# -27 muy frío
# -26 muy frío
# -25 muy frío
# -24 muy frío
# -23 muy frío
# -22 muy frío
# -21 muy frío
# -20 muy frío
# -19 muy frío
# -18 muy frío
# -17 muy frío
# -16 muy frío
# -15 muy frío
# -14 muy frío
# -13 muy frío
# -12 muy frío
# -11 muy frío
# -10 muy frío
# -9 muy frío
# -8 muy frío
# -7 muy frío
# -6 muy frío
# -5 muy frío
# -4 muy frío
# -3 muy frío
# -2 muy frío
# -1 muy frío
# 0 Templado
# 1 Templado
# 2 Templado
# 3 Templado
# 4 Templado
# 5 Templado
# 6 Templado
# 7 Templado
# 8 Templado
# 9 Templado
# 10 Templado
# 11 Templado
# 12 Templado
# 13 Templado
# 14 Templado
# 15 Templado
# 16 Templado
# 17 Templado
# 18 Templado
# 19 Templado
# 20 Templado
# 21 Templado
# 22 Templado
# 23 Templado
# 24 Templado
# 25 caluroso
# 26 caluroso
# 27 caluroso
# 28 caluroso
# 29 caluroso
# 30 caluroso
# 31 caluroso
# 32 caluroso
# 33 caluroso
# 34 caluroso
# 35 caluroso
# 36 caluroso
# 37 caluroso
# 38 caluroso
# 39 caluroso
# ...

# %%
# número del 1 al 100
# divisibles por 5
for x in range(100):

# se ajusto el valor para que vaya del 1 al 100 (y no del 0 al 99)
  numero = x + 1

# si el número es divisible por 5
  if numero % 5 == 0:

 # si además es divisible por 10, imprime "Bip Bip"
    if numero % 10 == 0 :
      print(numero, "Bip Bip")

# si no, solo imprime "bip"
    else:
      print(numero, "Bip")
# Out:
# 5 Bip
# 10 Bip Bip
# 15 Bip
# 20 Bip Bip
# 25 Bip
# 30 Bip Bip
# 35 Bip
# 40 Bip Bip
# 45 Bip
# 50 Bip Bip
# 55 Bip
# 60 Bip Bip
# 65 Bip
# 70 Bip Bip
# 75 Bip
# 80 Bip Bip
# 85 Bip
# 90 Bip Bip
# 95 Bip
# 100 Bip Bip

# %%
# se pide dos puntajes al usuario, se suma
# muestra el nivel según el resultado

# aqui se le pide al usuario que ingrese los puntajes
x = input("Ingresa primer puntaje:")
y = input("Ingresa segundo puntaje:")

# los datos pasan a números enteros para sumarlos
x = int(x)
y = int(y)

# se realiza la suma de los dos puntajes
suma = x+y

# según el resultado, se muestra el nivel
if suma < 50:
  print("Resultado: Nivel principiante")

elif suma >= 50 and suma < 80:
  print("Resultado: Nivel intermedio")

elif suma >= 80:
  print("Resultado: Nivel pro")
# Out:
# Ingresa primer puntaje:50
# Ingresa segundo puntaje:0
# Resultado: Nivel intermedio

# %%
# se evalúa el perfil musical de una persona segun edad y si le gusta bailar o la musica

# se le pide al usuario que ponga los datos
edad = input("edad:")
le_gusta_musica = input("le gusta la musica?:")
le_gusta_bailar = input("le gusta bailar?:")

# se convierte la edad a número entero
edad = int(edad)

# primero se revisa si le gusta la música
if le_gusta_musica == "si":

# después si le gusta bailar
  if le_gusta_bailar == "si":

# si le gusta la música, bailar y ademas tiene 18 o más
      if edad >= 18:
        print("Eres una estrella de la fiesta")
# si no cumple con la edad
      else:
        print("Tienes tu propio estilo")
# si le gusta la música pero no bailar
  else:
    print('Te gusta la musica pero no tanto bailar')
# en cualquier caso
else:
  print('Tienes tu propio estilo')
# Out:
# edad:90
# le gusta la musica?:si
# le gusta bailar?:si
# Eres una estrella de la fiesta
